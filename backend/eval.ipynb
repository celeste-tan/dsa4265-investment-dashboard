# %%
import os
import json
import pandas as pd
from pathlib import Path

# %%
import json
import pandas as pd
from pathlib import Path
import re

ROOT_DIR = Path("faithfulness_eval")
MODEL_FOLDERS = ["gemini-1.5-pro-latest", "hugging_face", "openai_gpt4o_mini"]
records = []

def infer_metadata(file_path):
    model = file_path.parent.name
    filename = file_path.name.lower()

    # Determine report type from filename
    if "stock_history" in filename:
        report_type = "stock_history"
    elif "media" in filename:
        report_type = "media"
    elif "financial" in filename:
        report_type = "financial"
    elif "esg" in filename:
        report_type = "esg"
    else:
        report_type = "unknown"

    # Try to find ticker in filename
    match = re.search(r"_([A-Z]{2,6})_(stock|media|financial|esg)", file_path.name.upper())
    ticker = match.group(1) if match else None
    return model, report_type, ticker

def infer_score_from_explanation(explanation):
    if not isinstance(explanation, str):
        return None
    text = explanation.lower()
    if "perfectly faithful" in text or "highly faithful" in text or "accurately reflects" in text:
        return 1.0
    elif "largely faithful" in text:
        return 0.9
    elif "somewhat faithful" in text:
        return 0.5
    elif "not faithful" in text or "unfaithful" in text or "error" in text:
        return 0.0
    return None

def parse_file(file):
    model, report_type, fallback_ticker = infer_metadata(file)

    try:
        with open(file, "r") as f:
            data = json.load(f)
    except Exception as e:
        print(f"❌ JSON error in {file.name}: {e}")
        return

    # === CASE 1: BATCH FILE ===
    if isinstance(data, dict) and all(isinstance(v, dict) for v in data.values()):
        for ticker, entry in data.items():
            fe = entry.get("Faithfulness Evaluation")
            if isinstance(fe, dict):
                score = fe.get("Score")
                explanation = fe.get("Explanation")
            else:
                score = None
                explanation = fe
            if score is None:
                score = infer_score_from_explanation(explanation)
            records.append({
                "Ticker": ticker.upper(),
                "Model": model,
                "Report Type": report_type,
                "Score": score,
                "Explanation": explanation,
                "Path": str(file)
            })

    # === CASE 2: SINGLE ENTRY ===
    elif isinstance(data, dict):
        ticker = data.get("Ticker", fallback_ticker)
        fe = data.get("Faithfulness Evaluation")
        if isinstance(fe, dict):
            score = fe.get("Score")
            explanation = fe.get("Explanation")
        else:
            score = None
            explanation = fe
        if score is None:
            score = infer_score_from_explanation(explanation)
        records.append({
            "Ticker": ticker.upper() if ticker else None,
            "Model": model,
            "Report Type": report_type,
            "Score": score,
            "Explanation": explanation,
            "Path": str(file)
        })

    else:
        print(f"⚠️ Unrecognized structure in {file.name}")

# Process all model folders
for model_folder in MODEL_FOLDERS:
    folder = ROOT_DIR / model_folder
    if not folder.exists():
        continue
    for file in folder.glob("*.json"):
        parse_file(file)

# Convert to DataFrame
df = pd.DataFrame(records)
print(f"✅ Loaded {len(df)} evaluations")
display(df.head(20))
# Out:
# ✅ Loaded 163 evaluations
#     Ticker                  Model    Report Type  Score  \
# 0    GOOGL  gemini-1.5-pro-latest  stock_history    NaN
# 1     MSFT  gemini-1.5-pro-latest          media   0.90
# 2     AMZN  gemini-1.5-pro-latest  stock_history    NaN
# 3   GOOGL   gemini-1.5-pro-latest          media   1.00
# 4     TSLA  gemini-1.5-pro-latest  stock_history    NaN
# 5     NFLX  gemini-1.5-pro-latest          media   0.90
# 6     META  gemini-1.5-pro-latest          media   0.90
# 7     META  gemini-1.5-pro-latest  stock_history    NaN
# 8     AAPL  gemini-1.5-pro-latest          media   0.90
# 9     TSLA  gemini-1.5-pro-latest            esg    NaN
# 10    NVDA  gemini-1.5-pro-latest            esg   0.00
# 11    AAPL  gemini-1.5-pro-latest            esg   0.00
# 12    MSFT  gemini-1.5-pro-latest            esg   0.00
# 13   GOOGL  gemini-1.5-pro-latest            esg   0.00
# 14    META  gemini-1.5-pro-latest            esg   0.00
# 15    AMZN  gemini-1.5-pro-latest            esg   0.00
# 16    PLTR  gemini-1.5-pro-latest            esg   0.95
# 17     AMD  gemini-1.5-pro-latest            esg   0.95
# 18    NFLX  gemini-1.5-pro-latest            esg   0.90
# 19   PLTR   gemini-1.5-pro-latest          media   0.00
#
#                                           Explanation  \
# 0                                                None
# 1   The generated report accurately reflects key p...
# 2                                                None
# 3   The generated report accurately reflects the a...
# 4                                                None
# 5   The generated report accurately reflects the m...
# 6   The generated report accurately summarizes sev...
# 7                                                None
# 8   The generated report accurately reflects sever...
# 9   Faithfulness Score: **0.85**\n\nExplanation:\n...
# 10  Error evaluating faithfulness: 429 You exceede...
# 11  Error evaluating faithfulness: 429 You exceede...
# 12  Error evaluating faithfulness: 429 You exceede...
# 13  Error evaluating faithfulness: 429 You exceede...
# 14  Error evaluating faithfulness: 429 You exceede...
# 15  Error evaluating faithfulness: 429 You exceede...
# 16  Faithfulness Explanation:\n\nThe report demons...
# 17  The report demonstrates high faithfulness to t...
# 18  Faithfulness Score: **0.9**\n\nExplanation:\n\...
# 19  The generated report claims that there are no ...
#
#                                                  Path
# 0   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 1   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 2   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 3   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 4   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 5   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 6   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 7   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 8   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 9   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 10  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 11  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 12  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 13  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 14  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 15  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 16  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 17  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 18  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 19  faithfulness_eval/gemini-1.5-pro-latest/2025-0...

# %%
# Ticker whitelist
TICKER_LIST = ["TSLA", "NVDA", "AAPL", "MSFT", "GOOGL", "META", "AMZN", "PLTR", "AMD", "NFLX"]

# Remove trailing spaces from tickers and filter
df["Ticker"] = df["Ticker"].str.strip()  # remove any whitespace
df = df[df["Ticker"].isin(TICKER_LIST)]

# Final display
print(f"✅ Filtered to {len(df)} evaluations for target tickers")
display(df.head(20))
# Out:
# ✅ Filtered to 147 evaluations for target tickers
#    Ticker                  Model    Report Type  Score  \
# 0   GOOGL  gemini-1.5-pro-latest  stock_history    NaN
# 1    MSFT  gemini-1.5-pro-latest          media   0.90
# 2    AMZN  gemini-1.5-pro-latest  stock_history    NaN
# 3   GOOGL  gemini-1.5-pro-latest          media   1.00
# 4    TSLA  gemini-1.5-pro-latest  stock_history    NaN
# 5    NFLX  gemini-1.5-pro-latest          media   0.90
# 6    META  gemini-1.5-pro-latest          media   0.90
# 7    META  gemini-1.5-pro-latest  stock_history    NaN
# 8    AAPL  gemini-1.5-pro-latest          media   0.90
# 9    TSLA  gemini-1.5-pro-latest            esg    NaN
# 10   NVDA  gemini-1.5-pro-latest            esg   0.00
# 11   AAPL  gemini-1.5-pro-latest            esg   0.00
# 12   MSFT  gemini-1.5-pro-latest            esg   0.00
# 13  GOOGL  gemini-1.5-pro-latest            esg   0.00
# 14   META  gemini-1.5-pro-latest            esg   0.00
# 15   AMZN  gemini-1.5-pro-latest            esg   0.00
# 16   PLTR  gemini-1.5-pro-latest            esg   0.95
# 17    AMD  gemini-1.5-pro-latest            esg   0.95
# 18   NFLX  gemini-1.5-pro-latest            esg   0.90
# 19   PLTR  gemini-1.5-pro-latest          media   0.00
#
#                                           Explanation  \
# 0                                                None
# 1   The generated report accurately reflects key p...
# 2                                                None
# 3   The generated report accurately reflects the a...
# 4                                                None
# 5   The generated report accurately reflects the m...
# 6   The generated report accurately summarizes sev...
# 7                                                None
# 8   The generated report accurately reflects sever...
# 9   Faithfulness Score: **0.85**\n\nExplanation:\n...
# 10  Error evaluating faithfulness: 429 You exceede...
# 11  Error evaluating faithfulness: 429 You exceede...
# 12  Error evaluating faithfulness: 429 You exceede...
# 13  Error evaluating faithfulness: 429 You exceede...
# 14  Error evaluating faithfulness: 429 You exceede...
# 15  Error evaluating faithfulness: 429 You exceede...
# 16  Faithfulness Explanation:\n\nThe report demons...
# 17  The report demonstrates high faithfulness to t...
# 18  Faithfulness Score: **0.9**\n\nExplanation:\n\...
# 19  The generated report claims that there are no ...
#
#                                                  Path
# 0   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 1   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 2   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 3   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 4   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 5   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 6   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 7   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 8   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 9   faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 10  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 11  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 12  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 13  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 14  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 15  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 16  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 17  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 18  faithfulness_eval/gemini-1.5-pro-latest/2025-0...
# 19  faithfulness_eval/gemini-1.5-pro-latest/2025-0...

# %%
df.to_csv("eval.csv")

# %%
# Average score per model
model_avg = df.groupby("Model")["Score"].mean().reset_index().sort_values("Score", ascending=False)
print("🔍 Average Faithfulness by Model:")
display(model_avg)

# Average score per report type
report_avg = df.groupby("Report Type")["Score"].mean().reset_index().sort_values("Score", ascending=False)
print("\n📄 Average Faithfulness by Report Type:")
display(report_avg)

# Average score per model + report type
combo_avg = df.groupby(["Model", "Report Type"])["Score"].mean().reset_index().sort_values("Score", ascending=False)
print("\n📊 Average Faithfulness by Model + Report Type:")
display(combo_avg)

# Average score per ticker (optional)
ticker_avg = df.groupby("Ticker")["Score"].mean().reset_index().sort_values("Score", ascending=False)
print("\n💹 Average Faithfulness by Ticker:")
display(ticker_avg)
# Out:
# 🔍 Average Faithfulness by Model:
#                    Model     Score
# 1           hugging_face  0.795000
# 0  gemini-1.5-pro-latest  0.610000
# 2      openai_gpt4o_mini  0.481579
# 📄 Average Faithfulness by Report Type:
#      Report Type     Score
# 3  stock_history  0.940000
# 2          media  0.859091
# 4        unknown  0.600000
# 1      financial  0.466176
# 0            esg  0.450000
# 📊 Average Faithfulness by Model + Report Type:
#                     Model    Report Type     Score
# 4            hugging_face            esg  1.000000
# 10      openai_gpt4o_mini  stock_history  0.940000
# 9       openai_gpt4o_mini          media  0.863636
# 2   gemini-1.5-pro-latest          media  0.854545
# 5            hugging_face      financial  0.785000
# 6            hugging_face        unknown  0.600000
# 8       openai_gpt4o_mini      financial  0.333333
# 7       openai_gpt4o_mini            esg  0.312903
# 0   gemini-1.5-pro-latest            esg  0.311111
# 1   gemini-1.5-pro-latest      financial       NaN
# 3   gemini-1.5-pro-latest  stock_history       NaN
# 💹 Average Faithfulness by Ticker:
#   Ticker     Score
# 5   MSFT  0.855556
# 3  GOOGL  0.644444
# 9   TSLA  0.600000
# 0   AAPL  0.593750
# 8   PLTR  0.550000
# 4   META  0.542857
# 7   NVDA  0.542857
# 6   NFLX  0.539286
# 1    AMD  0.525000
# 2   AMZN  0.485714
